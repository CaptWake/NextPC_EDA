# %% [markdown]
# ### Dependencies

# %%
import os
import json
import re

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Training Results Analysis

# %%
LOG_FILES = ['training.swinv2.base.log', 'training.swinv2.large.log', 'training.swinv2.small.log', 'training.swinv2.tiny.log']

# %%
PREPROC_MODES = ['basic', 'random', 'manual-1', 'manual-2', 'manual-3', 'all']
DATASETS = ['lab', 'lab+pasi', 'lab+maria']
MODELS = ['swinv2-tiny-patch4-window16-256', 'swinv2-small-patch4-window16-256', 'swinv2-base-patch4-window16-256', 'swinv2-large-patch4-window12-192-22k']

# %%
def decode(key):
    return {'model': MODELS[int(key[0])], 'dataset': DATASETS[int(key[1])], 'preprocess_mode': PREPROC_MODES[int(key[2])]}

# %%
def process_log(fname):
    payload = ""
    data = {}
    with open(fname, 'r') as f:
        payload = f.read()

    # performances = [{'epoch': round(float(perf[0])), 'test_acc': float(perf[1]), 'test_prec': float(perf[2]), 'test_rec': float(perf[3]), 'test_f1': float(perf[4])} for perf in re.findall('testset on epoch (\d+\.\d+) acc:  (\d\.\d+)  prec  (\d\.\d+)  rec  (\d\.\d+)  f1  (\d\.\d+)', payload)]
    payload = ''.join([match[0] for match in re.findall('((running|\{\'eval).*\n)', payload)])
    
    keys = list(map(lambda x: x[0]+x[1]+x[2], re.findall("(\d) -d (\d) -p (\d) \n", payload)))
    for key, experiment in zip(keys, re.split("running .* \n", payload)[1:]):
        data[key] = list(map(lambda x: json.loads(x), re.split("\n", experiment.replace('\'', '\"'))[:-1]))
    return [decode(key) | max(experiment, key=lambda x: x['eval_accuracy']) for key, experiment in data.items()]

# %%
results = []
for fname in LOG_FILES:
    results.extend(process_log(fname))

# %%
results
# Out:
# [{'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'all',
#   'eval_loss': 0.61958909034729,
#   'eval_accuracy': 0.9233333333333333,
#   'eval_runtime': 13.1582,
#   'eval_samples_per_second': 22.799,
#   'eval_steps_per_second': 5.7,
#   'epoch': 11.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'manual-3',
#   'eval_loss': 0.13319028913974762,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 12.1241,
#   'eval_samples_per_second': 24.744,
#   'eval_steps_per_second': 6.186,
#   'epoch': 9.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'manual-2',
#   'eval_loss': 0.10647806525230408,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 11.5768,
#   'eval_samples_per_second': 25.914,
#   'eval_steps_per_second': 6.478,
#   'epoch': 31.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'manual-1',
#   'eval_loss': 0.2614101767539978,
#   'eval_accuracy': 0.9633333333333334,
#   'eval_runtime': 13.0621,
#   'eval_samples_per_second': 22.967,
#   'eval_steps_per_second': 5.742,
#   'epoch': 32.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'random',
#   'eval_loss': 0.11104923486709595,
#   'eval_accuracy': 0.9866666666666667,
#   'eval_runtime': 10.4515,
#   'eval_samples_per_second': 28.704,
#   'eval_steps_per_second': 7.176,
#   'epoch': 31.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'basic',
#   'eval_loss': 0.202309250831604,
#   'eval_accuracy': 0.9866666666666667,
#   'eval_runtime': 10.1938,
#   'eval_samples_per_second': 29.43,
#   'eval_steps_per_second': 7.357,
#   'epoch': 31.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'all',
#   'eval_loss': 0.5101464986801147,
#   'eval_accuracy': 0.9366666666666666,
#   'eval_runtime': 13.4111,
#   'eval_samples_per_second': 22.37,
#   'eval_steps_per_second': 5.592,
#   'epoch': 25.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'manual-3',
#   'eval_loss': 0.13310407102108002,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 12.0474,
#   'eval_samples_per_second': 24.902,
#   'eval_steps_per_second': 6.225,
#   'epoch': 33.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'manual-2',
#   'eval_loss': 0.44746702909469604,
#   'eval_accuracy': 0.9333333333333333,
#   'eval_runtime': 12.2325,
#   'eval_samples_per_second': 24.525,
#   'eval_steps_per_second': 6.131,
#   'epoch': 4.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'manual-1',
#   'eval_loss': 0.2799801826477051,
#   'eval_accuracy': 0.9566666666666667,
#   'eval_runtime': 12.8854,
#   'eval_samples_per_second': 23.282,
#   'eval_steps_per_second': 5.821,
#   'epoch': 15.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'random',
#   'eval_loss': 0.1882135272026062,
#   'eval_accuracy': 0.98,
#   'eval_runtime': 10.7206,
#   'eval_samples_per_second': 27.984,
#   'eval_steps_per_second': 6.996,
#   'epoch': 25.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'basic',
#   'eval_loss': 0.2070349156856537,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 9.8847,
#   'eval_samples_per_second': 30.35,
#   'eval_steps_per_second': 7.588,
#   'epoch': 6.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'all',
#   'eval_loss': 0.46737661957740784,
#   'eval_accuracy': 0.9433333333333334,
#   'eval_runtime': 13.4676,
#   'eval_samples_per_second': 22.276,
#   'eval_steps_per_second': 5.569,
#   'epoch': 26.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'manual-3',
#   'eval_loss': 0.21086649596691132,
#   'eval_accuracy': 0.9766666666666667,
#   'eval_runtime': 11.8003,
#   'eval_samples_per_second': 25.423,
#   'eval_steps_per_second': 6.356,
#   'epoch': 36.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'manual-2',
#   'eval_loss': 0.19127240777015686,
#   'eval_accuracy': 0.98,
#   'eval_runtime': 12.3432,
#   'eval_samples_per_second': 24.305,
#   'eval_steps_per_second': 6.076,
#   'epoch': 23.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'manual-1',
#   'eval_loss': 0.3415088951587677,
#   'eval_accuracy': 0.9566666666666667,
#   'eval_runtime': 12.9961,
#   'eval_samples_per_second': 23.084,
#   'eval_steps_per_second': 5.771,
#   'epoch': 31.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'random',
#   'eval_loss': 0.1812603622674942,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 10.4975,
#   'eval_samples_per_second': 28.578,
#   'eval_steps_per_second': 7.145,
#   'epoch': 26.0},
#  {'model': 'swinv2-base-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'basic',
#   'eval_loss': 0.19382524490356445,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 9.8607,
#   'eval_samples_per_second': 30.424,
#   'eval_steps_per_second': 7.606,
#   'epoch': 5.0},
#  {'model': 'swinv2-large-patch4-window12-192-22k',
#   'dataset': 'lab',
#   'preprocess_mode': 'manual-2',
#   'eval_loss': 0.3908173739910126,
#   'eval_accuracy': 0.9533333333333334,
#   'eval_runtime': 7.6298,
#   'eval_samples_per_second': 39.32,
#   'eval_steps_per_second': 4.98,
#   'epoch': 23.0},
#  {'model': 'swinv2-large-patch4-window12-192-22k',
#   'dataset': 'lab',
#   'preprocess_mode': 'manual-1',
#   'eval_loss': 0.5835694074630737,
#   'eval_accuracy': 0.93,
#   'eval_runtime': 7.9341,
#   'eval_samples_per_second': 37.812,
#   'eval_steps_per_second': 4.789,
#   'epoch': 15.0},
#  {'model': 'swinv2-large-patch4-window12-192-22k',
#   'dataset': 'lab',
#   'preprocess_mode': 'random',
#   'eval_loss': 0.2827098071575165,
#   'eval_accuracy': 0.9666666666666667,
#   'eval_runtime': 7.0062,
#   'eval_samples_per_second': 42.819,
#   'eval_steps_per_second': 5.424,
#   'epoch': 7.0},
#  {'model': 'swinv2-large-patch4-window12-192-22k',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'manual-2',
#   'eval_loss': 0.4597185254096985,
#   'eval_accuracy': 0.95,
#   'eval_runtime': 10.1321,
#   'eval_samples_per_second': 29.609,
#   'eval_steps_per_second': 3.75,
#   'epoch': 21.0},
#  {'model': 'swinv2-large-patch4-window12-192-22k',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'manual-1',
#   'eval_loss': 0.5713238716125488,
#   'eval_accuracy': 0.93,
#   'eval_runtime': 7.7757,
#   'eval_samples_per_second': 38.582,
#   'eval_steps_per_second': 4.887,
#   'epoch': 14.0},
#  {'model': 'swinv2-large-patch4-window12-192-22k',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'random',
#   'eval_loss': 0.12076356261968613,
#   'eval_accuracy': 0.9666666666666667,
#   'eval_runtime': 7.2238,
#   'eval_samples_per_second': 41.529,
#   'eval_steps_per_second': 5.26,
#   'epoch': 3.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'all',
#   'eval_loss': 0.559956967830658,
#   'eval_accuracy': 0.9166666666666666,
#   'eval_runtime': 7.6357,
#   'eval_samples_per_second': 39.289,
#   'eval_steps_per_second': 4.977,
#   'epoch': 38.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'manual-3',
#   'eval_loss': 0.1574597805738449,
#   'eval_accuracy': 0.9766666666666667,
#   'eval_runtime': 7.0948,
#   'eval_samples_per_second': 42.285,
#   'eval_steps_per_second': 5.356,
#   'epoch': 36.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'manual-2',
#   'eval_loss': 0.2557154595851898,
#   'eval_accuracy': 0.96,
#   'eval_runtime': 7.3424,
#   'eval_samples_per_second': 40.859,
#   'eval_steps_per_second': 5.175,
#   'epoch': 12.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'manual-1',
#   'eval_loss': 0.25375640392303467,
#   'eval_accuracy': 0.9566666666666667,
#   'eval_runtime': 7.4119,
#   'eval_samples_per_second': 40.476,
#   'eval_steps_per_second': 5.127,
#   'epoch': 31.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'random',
#   'eval_loss': 0.18885737657546997,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 6.7569,
#   'eval_samples_per_second': 44.399,
#   'eval_steps_per_second': 5.624,
#   'epoch': 31.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'basic',
#   'eval_loss': 0.009247148409485817,
#   'eval_accuracy': 0.9966666666666667,
#   'eval_runtime': 6.3156,
#   'eval_samples_per_second': 47.501,
#   'eval_steps_per_second': 6.017,
#   'epoch': 9.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'all',
#   'eval_loss': 0.4100114405155182,
#   'eval_accuracy': 0.9266666666666666,
#   'eval_runtime': 7.714,
#   'eval_samples_per_second': 38.89,
#   'eval_steps_per_second': 4.926,
#   'epoch': 11.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'manual-3',
#   'eval_loss': 0.14212144911289215,
#   'eval_accuracy': 0.97,
#   'eval_runtime': 7.3398,
#   'eval_samples_per_second': 40.873,
#   'eval_steps_per_second': 5.177,
#   'epoch': 3.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'manual-2',
#   'eval_loss': 0.2034250646829605,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 7.4027,
#   'eval_samples_per_second': 40.526,
#   'eval_steps_per_second': 5.133,
#   'epoch': 38.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'manual-1',
#   'eval_loss': 0.2686241567134857,
#   'eval_accuracy': 0.97,
#   'eval_runtime': 7.7726,
#   'eval_samples_per_second': 38.597,
#   'eval_steps_per_second': 4.889,
#   'epoch': 27.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'random',
#   'eval_loss': 0.1325242519378662,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 6.9376,
#   'eval_samples_per_second': 43.243,
#   'eval_steps_per_second': 5.477,
#   'epoch': 35.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'basic',
#   'eval_loss': 0.2979966700077057,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 6.2151,
#   'eval_samples_per_second': 48.269,
#   'eval_steps_per_second': 6.114,
#   'epoch': 10.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'all',
#   'eval_loss': 0.4066603481769562,
#   'eval_accuracy': 0.9366666666666666,
#   'eval_runtime': 7.5238,
#   'eval_samples_per_second': 39.874,
#   'eval_steps_per_second': 5.051,
#   'epoch': 16.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'manual-3',
#   'eval_loss': 0.07035711407661438,
#   'eval_accuracy': 0.99,
#   'eval_runtime': 7.1224,
#   'eval_samples_per_second': 42.12,
#   'eval_steps_per_second': 5.335,
#   'epoch': 19.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'manual-2',
#   'eval_loss': 0.2606237530708313,
#   'eval_accuracy': 0.9733333333333334,
#   'eval_runtime': 7.151,
#   'eval_samples_per_second': 41.952,
#   'eval_steps_per_second': 5.314,
#   'epoch': 26.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'manual-1',
#   'eval_loss': 0.16438311338424683,
#   'eval_accuracy': 0.9766666666666667,
#   'eval_runtime': 7.4995,
#   'eval_samples_per_second': 40.003,
#   'eval_steps_per_second': 5.067,
#   'epoch': 27.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'random',
#   'eval_loss': 0.2312258929014206,
#   'eval_accuracy': 0.9766666666666667,
#   'eval_runtime': 6.7015,
#   'eval_samples_per_second': 44.766,
#   'eval_steps_per_second': 5.67,
#   'epoch': 39.0},
#  {'model': 'swinv2-small-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'basic',
#   'eval_loss': 0.18306632339954376,
#   'eval_accuracy': 0.9733333333333334,
#   'eval_runtime': 7.0618,
#   'eval_samples_per_second': 42.482,
#   'eval_steps_per_second': 5.381,
#   'epoch': 2.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'all',
#   'eval_loss': 0.5377573370933533,
#   'eval_accuracy': 0.9366666666666666,
#   'eval_runtime': 10.4963,
#   'eval_samples_per_second': 28.581,
#   'eval_steps_per_second': 7.145,
#   'epoch': 19.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'manual-3',
#   'eval_loss': 0.3306783437728882,
#   'eval_accuracy': 0.9666666666666667,
#   'eval_runtime': 9.7349,
#   'eval_samples_per_second': 30.817,
#   'eval_steps_per_second': 7.704,
#   'epoch': 23.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'manual-2',
#   'eval_loss': 0.2588573098182678,
#   'eval_accuracy': 0.9633333333333334,
#   'eval_runtime': 9.8487,
#   'eval_samples_per_second': 30.461,
#   'eval_steps_per_second': 7.615,
#   'epoch': 14.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'manual-1',
#   'eval_loss': 0.252657413482666,
#   'eval_accuracy': 0.97,
#   'eval_runtime': 10.7166,
#   'eval_samples_per_second': 27.994,
#   'eval_steps_per_second': 6.998,
#   'epoch': 31.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'random',
#   'eval_loss': 0.13903188705444336,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 7.4844,
#   'eval_samples_per_second': 40.084,
#   'eval_steps_per_second': 10.021,
#   'epoch': 14.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+maria',
#   'preprocess_mode': 'basic',
#   'eval_loss': 0.08300258964300156,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 6.5974,
#   'eval_samples_per_second': 45.472,
#   'eval_steps_per_second': 11.368,
#   'epoch': 5.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'all',
#   'eval_loss': 0.57419753074646,
#   'eval_accuracy': 0.9233333333333333,
#   'eval_runtime': 11.2718,
#   'eval_samples_per_second': 26.615,
#   'eval_steps_per_second': 6.654,
#   'epoch': 25.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'manual-3',
#   'eval_loss': 0.24727267026901245,
#   'eval_accuracy': 0.9833333333333333,
#   'eval_runtime': 9.6912,
#   'eval_samples_per_second': 30.956,
#   'eval_steps_per_second': 7.739,
#   'epoch': 14.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'manual-2',
#   'eval_loss': 0.40784400701522827,
#   'eval_accuracy': 0.9466666666666667,
#   'eval_runtime': 9.2511,
#   'eval_samples_per_second': 32.429,
#   'eval_steps_per_second': 8.107,
#   'epoch': 16.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'manual-1',
#   'eval_loss': 0.2680493891239166,
#   'eval_accuracy': 0.97,
#   'eval_runtime': 9.8364,
#   'eval_samples_per_second': 30.499,
#   'eval_steps_per_second': 7.625,
#   'epoch': 36.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'random',
#   'eval_loss': 0.13034659624099731,
#   'eval_accuracy': 0.9866666666666667,
#   'eval_runtime': 7.4616,
#   'eval_samples_per_second': 40.206,
#   'eval_steps_per_second': 10.051,
#   'epoch': 14.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab+pasi',
#   'preprocess_mode': 'basic',
#   'eval_loss': 0.04282616078853607,
#   'eval_accuracy': 0.9866666666666667,
#   'eval_runtime': 7.5307,
#   'eval_samples_per_second': 39.837,
#   'eval_steps_per_second': 9.959,
#   'epoch': 19.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'all',
#   'eval_loss': 0.5872997045516968,
#   'eval_accuracy': 0.92,
#   'eval_runtime': 11.1692,
#   'eval_samples_per_second': 26.86,
#   'eval_steps_per_second': 6.715,
#   'epoch': 25.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'manual-3',
#   'eval_loss': 0.25505056977272034,
#   'eval_accuracy': 0.97,
#   'eval_runtime': 9.3887,
#   'eval_samples_per_second': 31.953,
#   'eval_steps_per_second': 7.988,
#   'epoch': 25.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'manual-2',
#   'eval_loss': 0.43256428837776184,
#   'eval_accuracy': 0.96,
#   'eval_runtime': 9.7447,
#   'eval_samples_per_second': 30.786,
#   'eval_steps_per_second': 7.696,
#   'epoch': 36.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'manual-1',
#   'eval_loss': 0.2972179651260376,
#   'eval_accuracy': 0.9633333333333334,
#   'eval_runtime': 10.3411,
#   'eval_samples_per_second': 29.01,
#   'eval_steps_per_second': 7.253,
#   'epoch': 18.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'random',
#   'eval_loss': 0.18943703174591064,
#   'eval_accuracy': 0.9766666666666667,
#   'eval_runtime': 8.0206,
#   'eval_samples_per_second': 37.404,
#   'eval_steps_per_second': 9.351,
#   'epoch': 19.0},
#  {'model': 'swinv2-tiny-patch4-window16-256',
#   'dataset': 'lab',
#   'preprocess_mode': 'basic',
#   'eval_loss': 0.1800774186849594,
#   'eval_accuracy': 0.9866666666666667,
#   'eval_runtime': 6.256,
#   'eval_samples_per_second': 47.954,
#   'eval_steps_per_second': 11.988,
#   'epoch': 24.0}]

# %%
json.dump(results, open('experiments_results.json', 'w'))

# %%
df = pd.DataFrame(results)
df
# Out:
#                                    model    dataset preprocess_mode  \
# 0        swinv2-base-patch4-window16-256  lab+maria             all
# 1        swinv2-base-patch4-window16-256  lab+maria        manual-3
# 2        swinv2-base-patch4-window16-256  lab+maria        manual-2
# 3        swinv2-base-patch4-window16-256  lab+maria        manual-1
# 4        swinv2-base-patch4-window16-256  lab+maria          random
# 5        swinv2-base-patch4-window16-256  lab+maria           basic
# 6        swinv2-base-patch4-window16-256   lab+pasi             all
# 7        swinv2-base-patch4-window16-256   lab+pasi        manual-3
# 8        swinv2-base-patch4-window16-256   lab+pasi        manual-2
# 9        swinv2-base-patch4-window16-256   lab+pasi        manual-1
# 10       swinv2-base-patch4-window16-256   lab+pasi          random
# 11       swinv2-base-patch4-window16-256   lab+pasi           basic
# 12       swinv2-base-patch4-window16-256        lab             all
# 13       swinv2-base-patch4-window16-256        lab        manual-3
# 14       swinv2-base-patch4-window16-256        lab        manual-2
# 15       swinv2-base-patch4-window16-256        lab        manual-1
# 16       swinv2-base-patch4-window16-256        lab          random
# 17       swinv2-base-patch4-window16-256        lab           basic
# 18  swinv2-large-patch4-window12-192-22k        lab        manual-2
# 19  swinv2-large-patch4-window12-192-22k        lab        manual-1
# 20  swinv2-large-patch4-window12-192-22k        lab          random
# 21  swinv2-large-patch4-window12-192-22k   lab+pasi        manual-2
# 22  swinv2-large-patch4-window12-192-22k   lab+pasi        manual-1
# 23  swinv2-large-patch4-window12-192-22k   lab+pasi          random
# 24      swinv2-small-patch4-window16-256  lab+maria             all
# 25      swinv2-small-patch4-window16-256  lab+maria        manual-3
# 26      swinv2-small-patch4-window16-256  lab+maria        manual-2
# 27      swinv2-small-patch4-window16-256  lab+maria        manual-1
# 28      swinv2-small-patch4-window16-256  lab+maria          random
# 29      swinv2-small-patch4-window16-256  lab+maria           basic
# 30      swinv2-small-patch4-window16-256   lab+pasi             all
# 31      swinv2-small-patch4-window16-256   lab+pasi        manual-3
# 32      swinv2-small-patch4-window16-256   lab+pasi        manual-2
# 33      swinv2-small-patch4-window16-256   lab+pasi        manual-1
# 34      swinv2-small-patch4-window16-256   lab+pasi          random
# 35      swinv2-small-patch4-window16-256   lab+pasi           basic
# 36      swinv2-small-patch4-window16-256        lab             all
# 37      swinv2-small-patch4-window16-256        lab        manual-3
# 38      swinv2-small-patch4-window16-256        lab        manual-2
# 39      swinv2-small-patch4-window16-256        lab        manual-1
# 40      swinv2-small-patch4-window16-256        lab          random
# 41      swinv2-small-patch4-window16-256        lab           basic
# 42       swinv2-tiny-patch4-window16-256  lab+maria             all
# 43       swinv2-tiny-patch4-window16-256  lab+maria        manual-3
# 44       swinv2-tiny-patch4-window16-256  lab+maria        manual-2
# 45       swinv2-tiny-patch4-window16-256  lab+maria        manual-1
# 46       swinv2-tiny-patch4-window16-256  lab+maria          random
# 47       swinv2-tiny-patch4-window16-256  lab+maria           basic
# 48       swinv2-tiny-patch4-window16-256   lab+pasi             all
# 49       swinv2-tiny-patch4-window16-256   lab+pasi        manual-3
# 50       swinv2-tiny-patch4-window16-256   lab+pasi        manual-2
# 51       swinv2-tiny-patch4-window16-256   lab+pasi        manual-1
# 52       swinv2-tiny-patch4-window16-256   lab+pasi          random
# 53       swinv2-tiny-patch4-window16-256   lab+pasi           basic
# 54       swinv2-tiny-patch4-window16-256        lab             all
# 55       swinv2-tiny-patch4-window16-256        lab        manual-3
# 56       swinv2-tiny-patch4-window16-256        lab        manual-2
# 57       swinv2-tiny-patch4-window16-256        lab        manual-1
# 58       swinv2-tiny-patch4-window16-256        lab          random
# 59       swinv2-tiny-patch4-window16-256        lab           basic
#
#     eval_loss  eval_accuracy  eval_runtime  eval_samples_per_second  \
# 0    0.619589       0.923333       13.1582                   22.799
# 1    0.133190       0.983333       12.1241                   24.744
# 2    0.106478       0.983333       11.5768                   25.914
# 3    0.261410       0.963333       13.0621                   22.967
# 4    0.111049       0.986667       10.4515                   28.704
# 5    0.202309       0.986667       10.1938                   29.430
# 6    0.510146       0.936667       13.4111                   22.370
# 7    0.133104       0.983333       12.0474                   24.902
# 8    0.447467       0.933333       12.2325                   24.525
# 9    0.279980       0.956667       12.8854                   23.282
# 10   0.188214       0.980000       10.7206                   27.984
# 11   0.207035       0.983333        9.8847                   30.350
# 12   0.467377       0.943333       13.4676                   22.276
# 13   0.210866       0.976667       11.8003                   25.423
# 14   0.191272       0.980000       12.3432                   24.305
# 15   0.341509       0.956667       12.9961                   23.084
# 16   0.181260       0.983333       10.4975                   28.578
# 17   0.193825       0.983333        9.8607                   30.424
# 18   0.390817       0.953333        7.6298                   39.320
# 19   0.583569       0.930000        7.9341                   37.812
# 20   0.282710       0.966667        7.0062                   42.819
# 21   0.459719       0.950000       10.1321                   29.609
# 22   0.571324       0.930000        7.7757                   38.582
# 23   0.120764       0.966667        7.2238                   41.529
# 24   0.559957       0.916667        7.6357                   39.289
# 25   0.157460       0.976667        7.0948                   42.285
# 26   0.255715       0.960000        7.3424                   40.859
# 27   0.253756       0.956667        7.4119                   40.476
# 28   0.188857       0.983333        6.7569                   44.399
# 29   0.009247       0.996667        6.3156                   47.501
# 30   0.410011       0.926667        7.7140                   38.890
# 31   0.142121       0.970000        7.3398                   40.873
# 32   0.203425       0.983333        7.4027                   40.526
# 33   0.268624       0.970000        7.7726                   38.597
# 34   0.132524       0.983333        6.9376                   43.243
# 35   0.297997       0.983333        6.2151                   48.269
# 36   0.406660       0.936667        7.5238                   39.874
# 37   0.070357       0.990000        7.1224                   42.120
# 38   0.260624       0.973333        7.1510                   41.952
# 39   0.164383       0.976667        7.4995                   40.003
# 40   0.231226       0.976667        6.7015                   44.766
# 41   0.183066       0.973333        7.0618                   42.482
# 42   0.537757       0.936667       10.4963                   28.581
# 43   0.330678       0.966667        9.7349                   30.817
# 44   0.258857       0.963333        9.8487                   30.461
# 45   0.252657       0.970000       10.7166                   27.994
# 46   0.139032       0.983333        7.4844                   40.084
# 47   0.083003       0.983333        6.5974                   45.472
# 48   0.574198       0.923333       11.2718                   26.615
# 49   0.247273       0.983333        9.6912                   30.956
# 50   0.407844       0.946667        9.2511                   32.429
# 51   0.268049       0.970000        9.8364                   30.499
# 52   0.130347       0.986667        7.4616                   40.206
# 53   0.042826       0.986667        7.5307                   39.837
# 54   0.587300       0.920000       11.1692                   26.860
# 55   0.255051       0.970000        9.3887                   31.953
# 56   0.432564       0.960000        9.7447                   30.786
# 57   0.297218       0.963333       10.3411                   29.010
# 58   0.189437       0.976667        8.0206                   37.404
# 59   0.180077       0.986667        6.2560                   47.954
#
#     eval_steps_per_second  epoch
# 0                   5.700   11.0
# 1                   6.186    9.0
# 2                   6.478   31.0
# 3                   5.742   32.0
# 4                   7.176   31.0
# 5                   7.357   31.0
# 6                   5.592   25.0
# 7                   6.225   33.0
# 8                   6.131    4.0
# 9                   5.821   15.0
# 10                  6.996   25.0
# 11                  7.588    6.0
# 12                  5.569   26.0
# 13                  6.356   36.0
# 14                  6.076   23.0
# 15                  5.771   31.0
# 16                  7.145   26.0
# 17                  7.606    5.0
# 18                  4.980   23.0
# 19                  4.789   15.0
# 20                  5.424    7.0
# 21                  3.750   21.0
# 22                  4.887   14.0
# 23                  5.260    3.0
# 24                  4.977   38.0
# 25                  5.356   36.0
# 26                  5.175   12.0
# 27                  5.127   31.0
# 28                  5.624   31.0
# 29                  6.017    9.0
# 30                  4.926   11.0
# 31                  5.177    3.0
# 32                  5.133   38.0
# 33                  4.889   27.0
# 34                  5.477   35.0
# 35                  6.114   10.0
# 36                  5.051   16.0
# 37                  5.335   19.0
# 38                  5.314   26.0
# 39                  5.067   27.0
# 40                  5.670   39.0
# 41                  5.381    2.0
# 42                  7.145   19.0
# 43                  7.704   23.0
# 44                  7.615   14.0
# 45                  6.998   31.0
# 46                 10.021   14.0
# 47                 11.368    5.0
# 48                  6.654   25.0
# 49                  7.739   14.0
# 50                  8.107   16.0
# 51                  7.625   36.0
# 52                 10.051   14.0
# 53                  9.959   19.0
# 54                  6.715   25.0
# 55                  7.988   25.0
# 56                  7.696   36.0
# 57                  7.253   18.0
# 58                  9.351   19.0
# 59                 11.988   24.0

# %%
# df['preprocess_mode'].replace(PREPROC_MODES, [0, 1, 2, 3, 4, 5])

# %%
sns.barplot(df,x='model', y='eval_accuracy', hue='preprocess_mode')
plt.xticks(rotation=45)
plt.savefig('results.png')

# %%
df.to_csv('results.csv')

# %%
for result in results:
    result['model'], result['dataset'], result['preprocess_mode']
    print('_'.join([result['model'], result['dataset'], result['preprocess_mode']]))
# Out:
# swinv2-base-patch4-window16-256_lab+maria_all
# swinv2-base-patch4-window16-256_lab+maria_manual-3
# swinv2-base-patch4-window16-256_lab+maria_manual-2
# swinv2-base-patch4-window16-256_lab+maria_manual-1
# swinv2-base-patch4-window16-256_lab+maria_random
# swinv2-base-patch4-window16-256_lab+maria_basic
# swinv2-base-patch4-window16-256_lab+pasi_all
# swinv2-base-patch4-window16-256_lab+pasi_manual-3
# swinv2-base-patch4-window16-256_lab+pasi_manual-2
# swinv2-base-patch4-window16-256_lab+pasi_manual-1
# swinv2-base-patch4-window16-256_lab+pasi_random
# swinv2-base-patch4-window16-256_lab+pasi_basic
# swinv2-base-patch4-window16-256_lab_all
# swinv2-base-patch4-window16-256_lab_manual-3
# swinv2-base-patch4-window16-256_lab_manual-2
# swinv2-base-patch4-window16-256_lab_manual-1
# swinv2-base-patch4-window16-256_lab_random
# swinv2-base-patch4-window16-256_lab_basic
# swinv2-large-patch4-window12-192-22k_lab_manual-2
# swinv2-large-patch4-window12-192-22k_lab_manual-1
# swinv2-large-patch4-window12-192-22k_lab_random
# swinv2-large-patch4-window12-192-22k_lab+pasi_manual-2
# swinv2-large-patch4-window12-192-22k_lab+pasi_manual-1
# swinv2-large-patch4-window12-192-22k_lab+pasi_random
# swinv2-small-patch4-window16-256_lab+maria_all
# swinv2-small-patch4-window16-256_lab+maria_manual-3
# swinv2-small-patch4-window16-256_lab+maria_manual-2
# swinv2-small-patch4-window16-256_lab+maria_manual-1
# swinv2-small-patch4-window16-256_lab+maria_random
# swinv2-small-patch4-window16-256_lab+maria_basic
# swinv2-small-patch4-window16-256_lab+pasi_all
# swinv2-small-patch4-window16-256_lab+pasi_manual-3
# swinv2-small-patch4-window16-256_lab+pasi_manual-2
# swinv2-small-patch4-window16-256_lab+pasi_manual-1
# swinv2-small-patch4-window16-256_lab+pasi_random
# swinv2-small-patch4-window16-256_lab+pasi_basic
# swinv2-small-patch4-window16-256_lab_all
# swinv2-small-patch4-window16-256_lab_manual-3
# swinv2-small-patch4-window16-256_lab_manual-2
# swinv2-small-patch4-window16-256_lab_manual-1
# swinv2-small-patch4-window16-256_lab_random
# swinv2-small-patch4-window16-256_lab_basic
# swinv2-tiny-patch4-window16-256_lab+maria_all
# swinv2-tiny-patch4-window16-256_lab+maria_manual-3
# swinv2-tiny-patch4-window16-256_lab+maria_manual-2
# swinv2-tiny-patch4-window16-256_lab+maria_manual-1
# swinv2-tiny-patch4-window16-256_lab+maria_random
# swinv2-tiny-patch4-window16-256_lab+maria_basic
# swinv2-tiny-patch4-window16-256_lab+pasi_all
# swinv2-tiny-patch4-window16-256_lab+pasi_manual-3
# swinv2-tiny-patch4-window16-256_lab+pasi_manual-2
# swinv2-tiny-patch4-window16-256_lab+pasi_manual-1
# swinv2-tiny-patch4-window16-256_lab+pasi_random
# swinv2-tiny-patch4-window16-256_lab+pasi_basic
# swinv2-tiny-patch4-window16-256_lab_all
# swinv2-tiny-patch4-window16-256_lab_manual-3
# swinv2-tiny-patch4-window16-256_lab_manual-2
# swinv2-tiny-patch4-window16-256_lab_manual-1
# swinv2-tiny-patch4-window16-256_lab_random
# swinv2-tiny-patch4-window16-256_lab_basic

# %% [markdown]
# ### Test Results Analysis

# %%
def process_test_logs(fname):
    payload = ""
    data = []
    with open(fname, 'r') as f:
        payload = f.read()

    for perf in re.findall('checkpoint: (.*/checkpoint-\d+) acc: (\d\.\d+) prec: (\d\.\d+) rec: (\d\.\d+) f1: (\d\.\d+)', payload):
        model, performance_mode, dataset = perf[0].split('/results_paper/')[1].split('/checkpoint')[0].split('_')
        data.append({'model': model, 'preprocess_mode': performance_mode, 'dataset': dataset, 'test_acc': float(perf[1]), 'test_prec': float(perf[2]), 'test_rec': float(perf[3]), 'test_f1': float(perf[4])})       
    #performances = [{'model': perf[0].split('/results_paper/')[1].split('/checkpoint')[0].split('_'), 'test_acc': float(perf[1]), 'test_prec': float(perf[2]), 'test_rec': float(perf[3]), 'test_f1': float(perf[4])} ]
    return data

# %%
df = pd.DataFrame(process_test_logs('./perf_test.logs'))
df
# Out:
#                                    model preprocess_mode    dataset  test_acc  \
# 0        swinv2-base-patch4-window16-256             all  lab+maria  0.743750
# 1        swinv2-base-patch4-window16-256        manual-3  lab+maria  0.700000
# 2        swinv2-base-patch4-window16-256        manual-2  lab+maria  0.671875
# 3        swinv2-base-patch4-window16-256        manual-1  lab+maria  0.656250
# 4        swinv2-base-patch4-window16-256          random  lab+maria  0.631250
# 5        swinv2-base-patch4-window16-256           basic  lab+maria  0.528125
# 6        swinv2-base-patch4-window16-256             all   lab+pasi  0.795000
# 7        swinv2-base-patch4-window16-256        manual-3   lab+pasi  0.832500
# 8        swinv2-base-patch4-window16-256        manual-2   lab+pasi  0.707500
# 9        swinv2-base-patch4-window16-256        manual-1   lab+pasi  0.802500
# 10       swinv2-base-patch4-window16-256          random   lab+pasi  0.740000
# 11       swinv2-base-patch4-window16-256           basic   lab+pasi  0.782500
# 12       swinv2-base-patch4-window16-256             all        lab  0.501389
# 13       swinv2-base-patch4-window16-256        manual-3        lab  0.490278
# 14       swinv2-base-patch4-window16-256        manual-2        lab  0.483333
# 15       swinv2-base-patch4-window16-256        manual-1        lab  0.416667
# 16       swinv2-base-patch4-window16-256          random        lab  0.583333
# 17       swinv2-base-patch4-window16-256           basic        lab  0.304167
# 18  swinv2-large-patch4-window12-192-22k        manual-2        lab  0.572222
# 19  swinv2-large-patch4-window12-192-22k        manual-1        lab  0.488889
# 20  swinv2-large-patch4-window12-192-22k          random        lab  0.413889
# 21  swinv2-large-patch4-window12-192-22k        manual-2   lab+pasi  0.757500
# 22  swinv2-large-patch4-window12-192-22k        manual-1   lab+pasi  0.765000
# 23  swinv2-large-patch4-window12-192-22k          random   lab+pasi  0.795000
# 24      swinv2-small-patch4-window16-256             all  lab+maria  0.671875
# 25      swinv2-small-patch4-window16-256        manual-3  lab+maria  0.596875
# 26      swinv2-small-patch4-window16-256        manual-2  lab+maria  0.718750
# 27      swinv2-small-patch4-window16-256        manual-1  lab+maria  0.646875
# 28      swinv2-small-patch4-window16-256          random  lab+maria  0.665625
# 29      swinv2-small-patch4-window16-256           basic  lab+maria  0.540625
# 30      swinv2-small-patch4-window16-256             all   lab+pasi  0.757500
# 31      swinv2-small-patch4-window16-256        manual-3   lab+pasi  0.822500
# 32      swinv2-small-patch4-window16-256        manual-2   lab+pasi  0.840000
# 33      swinv2-small-patch4-window16-256        manual-1   lab+pasi  0.840000
# 34      swinv2-small-patch4-window16-256          random   lab+pasi  0.877500
# 35      swinv2-small-patch4-window16-256           basic   lab+pasi  0.735000
# 36      swinv2-small-patch4-window16-256             all        lab  0.559722
# 37      swinv2-small-patch4-window16-256        manual-3        lab  0.477778
# 38      swinv2-small-patch4-window16-256        manual-2        lab  0.627778
# 39      swinv2-small-patch4-window16-256        manual-1        lab  0.459722
# 40      swinv2-small-patch4-window16-256          random        lab  0.568056
# 41      swinv2-small-patch4-window16-256           basic        lab  0.405556
# 42       swinv2-tiny-patch4-window16-256             all  lab+maria  0.590625
# 43       swinv2-tiny-patch4-window16-256        manual-3  lab+maria  0.625000
# 44       swinv2-tiny-patch4-window16-256        manual-2  lab+maria  0.596875
# 45       swinv2-tiny-patch4-window16-256        manual-1  lab+maria  0.631250
# 46       swinv2-tiny-patch4-window16-256          random  lab+maria  0.562500
# 47       swinv2-tiny-patch4-window16-256           basic  lab+maria  0.609375
# 48       swinv2-tiny-patch4-window16-256             all   lab+pasi  0.745000
# 49       swinv2-tiny-patch4-window16-256        manual-3   lab+pasi  0.810000
# 50       swinv2-tiny-patch4-window16-256        manual-2   lab+pasi  0.737500
# 51       swinv2-tiny-patch4-window16-256        manual-1   lab+pasi  0.795000
# 52       swinv2-tiny-patch4-window16-256          random   lab+pasi  0.785000
# 53       swinv2-tiny-patch4-window16-256           basic   lab+pasi  0.755000
# 54       swinv2-tiny-patch4-window16-256             all        lab  0.452778
# 55       swinv2-tiny-patch4-window16-256        manual-3        lab  0.416667
# 56       swinv2-tiny-patch4-window16-256        manual-2        lab  0.430556
# 57       swinv2-tiny-patch4-window16-256        manual-1        lab  0.472222
# 58       swinv2-tiny-patch4-window16-256          random        lab  0.354167
# 59       swinv2-tiny-patch4-window16-256           basic        lab  0.180556
#
#     test_prec  test_rec   test_f1
# 0    0.777952  0.743750  0.711543
# 1    0.692500  0.700000  0.664997
# 2    0.685011  0.671875  0.641260
# 3    0.661411  0.656250  0.613353
# 4    0.659531  0.631250  0.594550
# 5    0.611309  0.528125  0.510859
# 6    0.839236  0.795000  0.767389
# 7    0.878171  0.832500  0.820845
# 8    0.777799  0.707500  0.657704
# 9    0.846665  0.802500  0.796293
# 10   0.793735  0.740000  0.719846
# 11   0.842084  0.782500  0.765571
# 12   0.641404  0.501389  0.444899
# 13   0.544983  0.490278  0.463175
# 14   0.668658  0.483333  0.426441
# 15   0.452234  0.416667  0.381427
# 16   0.597765  0.583333  0.532126
# 17   0.476057  0.304167  0.244745
# 18   0.634805  0.572222  0.541793
# 19   0.645986  0.488889  0.447153
# 20   0.576080  0.413889  0.365102
# 21   0.817594  0.757500  0.712018
# 22   0.787219  0.765000  0.723954
# 23   0.849810  0.795000  0.782071
# 24   0.700629  0.671875  0.648100
# 25   0.662897  0.596875  0.563014
# 26   0.687883  0.718750  0.688031
# 27   0.678869  0.646875  0.631332
# 28   0.675970  0.665625  0.635814
# 29   0.634486  0.540625  0.506399
# 30   0.820152  0.757500  0.749397
# 31   0.876886  0.822500  0.808356
# 32   0.880383  0.840000  0.830002
# 33   0.878524  0.840000  0.825439
# 34   0.899073  0.877500  0.866227
# 35   0.813555  0.735000  0.709561
# 36   0.596871  0.559722  0.519156
# 37   0.619818  0.477778  0.425253
# 38   0.697485  0.627778  0.604115
# 39   0.470597  0.459722  0.421735
# 40   0.719428  0.568056  0.549066
# 41   0.608672  0.405556  0.395741
# 42   0.533823  0.590625  0.514629
# 43   0.647941  0.625000  0.598170
# 44   0.633260  0.596875  0.547491
# 45   0.649074  0.631250  0.593577
# 46   0.574394  0.562500  0.537072
# 47   0.635656  0.609375  0.597642
# 48   0.785938  0.745000  0.717422
# 49   0.832602  0.810000  0.806229
# 50   0.796585  0.737500  0.708408
# 51   0.830930  0.795000  0.773133
# 52   0.848302  0.785000  0.765694
# 53   0.799722  0.755000  0.725115
# 54   0.511708  0.452778  0.402263
# 55   0.560721  0.416667  0.387171
# 56   0.529357  0.430556  0.389066
# 57   0.563202  0.472222  0.436364
# 58   0.461622  0.354167  0.294443
# 59   0.373225  0.180556  0.134129

# %%
max_acc_rows = df.groupby(['model', 'preprocess_mode'])['test_acc'].idxmax()
df.loc[max_acc_rows]
# Out:
#                                    model preprocess_mode   dataset  test_acc  \
# 6        swinv2-base-patch4-window16-256             all  lab+pasi    0.7950
# 11       swinv2-base-patch4-window16-256           basic  lab+pasi    0.7825
# 9        swinv2-base-patch4-window16-256        manual-1  lab+pasi    0.8025
# 8        swinv2-base-patch4-window16-256        manual-2  lab+pasi    0.7075
# 7        swinv2-base-patch4-window16-256        manual-3  lab+pasi    0.8325
# 10       swinv2-base-patch4-window16-256          random  lab+pasi    0.7400
# 22  swinv2-large-patch4-window12-192-22k        manual-1  lab+pasi    0.7650
# 21  swinv2-large-patch4-window12-192-22k        manual-2  lab+pasi    0.7575
# 23  swinv2-large-patch4-window12-192-22k          random  lab+pasi    0.7950
# 30      swinv2-small-patch4-window16-256             all  lab+pasi    0.7575
# 35      swinv2-small-patch4-window16-256           basic  lab+pasi    0.7350
# 33      swinv2-small-patch4-window16-256        manual-1  lab+pasi    0.8400
# 32      swinv2-small-patch4-window16-256        manual-2  lab+pasi    0.8400
# 31      swinv2-small-patch4-window16-256        manual-3  lab+pasi    0.8225
# 34      swinv2-small-patch4-window16-256          random  lab+pasi    0.8775
# 48       swinv2-tiny-patch4-window16-256             all  lab+pasi    0.7450
# 53       swinv2-tiny-patch4-window16-256           basic  lab+pasi    0.7550
# 51       swinv2-tiny-patch4-window16-256        manual-1  lab+pasi    0.7950
# 50       swinv2-tiny-patch4-window16-256        manual-2  lab+pasi    0.7375
# 49       swinv2-tiny-patch4-window16-256        manual-3  lab+pasi    0.8100
# 52       swinv2-tiny-patch4-window16-256          random  lab+pasi    0.7850
#
#     test_prec  test_rec   test_f1
# 6    0.839236    0.7950  0.767389
# 11   0.842084    0.7825  0.765571
# 9    0.846665    0.8025  0.796293
# 8    0.777799    0.7075  0.657704
# 7    0.878171    0.8325  0.820845
# 10   0.793735    0.7400  0.719846
# 22   0.787219    0.7650  0.723954
# 21   0.817594    0.7575  0.712018
# 23   0.849810    0.7950  0.782071
# 30   0.820152    0.7575  0.749397
# 35   0.813555    0.7350  0.709561
# 33   0.878524    0.8400  0.825439
# 32   0.880383    0.8400  0.830002
# 31   0.876886    0.8225  0.808356
# 34   0.899073    0.8775  0.866227
# 48   0.785938    0.7450  0.717422
# 53   0.799722    0.7550  0.725115
# 51   0.830930    0.7950  0.773133
# 50   0.796585    0.7375  0.708408
# 49   0.832602    0.8100  0.806229
# 52   0.848302    0.7850  0.765694

# %%
sns.barplot(df.loc[max_acc_rows], x='model', y='test_acc', hue='preprocess_mode')
plt.xticks(rotation=45)
plt.savefig('results.png')

# %%
max_acc_rows = df.groupby(['model', 'dataset'])['test_acc'].idxmax()
df.loc[max_acc_rows]
# Out:
#                                    model preprocess_mode    dataset  test_acc  \
# 16       swinv2-base-patch4-window16-256          random        lab  0.583333
# 0        swinv2-base-patch4-window16-256             all  lab+maria  0.743750
# 7        swinv2-base-patch4-window16-256        manual-3   lab+pasi  0.832500
# 18  swinv2-large-patch4-window12-192-22k        manual-2        lab  0.572222
# 23  swinv2-large-patch4-window12-192-22k          random   lab+pasi  0.795000
# 38      swinv2-small-patch4-window16-256        manual-2        lab  0.627778
# 26      swinv2-small-patch4-window16-256        manual-2  lab+maria  0.718750
# 34      swinv2-small-patch4-window16-256          random   lab+pasi  0.877500
# 57       swinv2-tiny-patch4-window16-256        manual-1        lab  0.472222
# 45       swinv2-tiny-patch4-window16-256        manual-1  lab+maria  0.631250
# 49       swinv2-tiny-patch4-window16-256        manual-3   lab+pasi  0.810000
#
#     test_prec  test_rec   test_f1
# 16   0.597765  0.583333  0.532126
# 0    0.777952  0.743750  0.711543
# 7    0.878171  0.832500  0.820845
# 18   0.634805  0.572222  0.541793
# 23   0.849810  0.795000  0.782071
# 38   0.697485  0.627778  0.604115
# 26   0.687883  0.718750  0.688031
# 34   0.899073  0.877500  0.866227
# 57   0.563202  0.472222  0.436364
# 45   0.649074  0.631250  0.593577
# 49   0.832602  0.810000  0.806229

# %%
sns.barplot(df.loc[max_acc_rows], x='model', y='test_acc', hue='dataset')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'swinv2-base-patch4-window16-256'),
#   Text(1, 0, 'swinv2-large-patch4-window12-192-22k'),
#   Text(2, 0, 'swinv2-small-patch4-window16-256'),
#   Text(3, 0, 'swinv2-tiny-patch4-window16-256')])

# %%
max_acc_rows = df.groupby(['preprocess_mode', 'dataset'])['test_acc'].idxmax()
df.loc[max_acc_rows]
# Out:
#                                    model preprocess_mode    dataset  test_acc  \
# 36      swinv2-small-patch4-window16-256             all        lab  0.559722
# 0        swinv2-base-patch4-window16-256             all  lab+maria  0.743750
# 6        swinv2-base-patch4-window16-256             all   lab+pasi  0.795000
# 41      swinv2-small-patch4-window16-256           basic        lab  0.405556
# 47       swinv2-tiny-patch4-window16-256           basic  lab+maria  0.609375
# 11       swinv2-base-patch4-window16-256           basic   lab+pasi  0.782500
# 19  swinv2-large-patch4-window12-192-22k        manual-1        lab  0.488889
# 3        swinv2-base-patch4-window16-256        manual-1  lab+maria  0.656250
# 33      swinv2-small-patch4-window16-256        manual-1   lab+pasi  0.840000
# 38      swinv2-small-patch4-window16-256        manual-2        lab  0.627778
# 26      swinv2-small-patch4-window16-256        manual-2  lab+maria  0.718750
# 32      swinv2-small-patch4-window16-256        manual-2   lab+pasi  0.840000
# 13       swinv2-base-patch4-window16-256        manual-3        lab  0.490278
# 1        swinv2-base-patch4-window16-256        manual-3  lab+maria  0.700000
# 7        swinv2-base-patch4-window16-256        manual-3   lab+pasi  0.832500
# 16       swinv2-base-patch4-window16-256          random        lab  0.583333
# 28      swinv2-small-patch4-window16-256          random  lab+maria  0.665625
# 34      swinv2-small-patch4-window16-256          random   lab+pasi  0.877500
#
#     test_prec  test_rec   test_f1
# 36   0.596871  0.559722  0.519156
# 0    0.777952  0.743750  0.711543
# 6    0.839236  0.795000  0.767389
# 41   0.608672  0.405556  0.395741
# 47   0.635656  0.609375  0.597642
# 11   0.842084  0.782500  0.765571
# 19   0.645986  0.488889  0.447153
# 3    0.661411  0.656250  0.613353
# 33   0.878524  0.840000  0.825439
# 38   0.697485  0.627778  0.604115
# 26   0.687883  0.718750  0.688031
# 32   0.880383  0.840000  0.830002
# 13   0.544983  0.490278  0.463175
# 1    0.692500  0.700000  0.664997
# 7    0.878171  0.832500  0.820845
# 16   0.597765  0.583333  0.532126
# 28   0.675970  0.665625  0.635814
# 34   0.899073  0.877500  0.866227

# %%
sns.barplot(df.loc[max_acc_rows], x='preprocess_mode', y='test_acc', hue='dataset')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'all'),
#   Text(1, 0, 'basic'),
#   Text(2, 0, 'manual-1'),
#   Text(3, 0, 'manual-2'),
#   Text(4, 0, 'manual-3'),
#   Text(5, 0, 'random')])

# %%
max_acc_rows = df.groupby(['dataset', 'preprocess_mode'])['test_acc'].idxmax()
df.loc[max_acc_rows]
# Out:
#                                    model preprocess_mode    dataset  test_acc  \
# 36      swinv2-small-patch4-window16-256             all        lab  0.559722
# 41      swinv2-small-patch4-window16-256           basic        lab  0.405556
# 19  swinv2-large-patch4-window12-192-22k        manual-1        lab  0.488889
# 38      swinv2-small-patch4-window16-256        manual-2        lab  0.627778
# 13       swinv2-base-patch4-window16-256        manual-3        lab  0.490278
# 16       swinv2-base-patch4-window16-256          random        lab  0.583333
# 0        swinv2-base-patch4-window16-256             all  lab+maria  0.743750
# 47       swinv2-tiny-patch4-window16-256           basic  lab+maria  0.609375
# 3        swinv2-base-patch4-window16-256        manual-1  lab+maria  0.656250
# 26      swinv2-small-patch4-window16-256        manual-2  lab+maria  0.718750
# 1        swinv2-base-patch4-window16-256        manual-3  lab+maria  0.700000
# 28      swinv2-small-patch4-window16-256          random  lab+maria  0.665625
# 6        swinv2-base-patch4-window16-256             all   lab+pasi  0.795000
# 11       swinv2-base-patch4-window16-256           basic   lab+pasi  0.782500
# 33      swinv2-small-patch4-window16-256        manual-1   lab+pasi  0.840000
# 32      swinv2-small-patch4-window16-256        manual-2   lab+pasi  0.840000
# 7        swinv2-base-patch4-window16-256        manual-3   lab+pasi  0.832500
# 34      swinv2-small-patch4-window16-256          random   lab+pasi  0.877500
#
#     test_prec  test_rec   test_f1
# 36   0.596871  0.559722  0.519156
# 41   0.608672  0.405556  0.395741
# 19   0.645986  0.488889  0.447153
# 38   0.697485  0.627778  0.604115
# 13   0.544983  0.490278  0.463175
# 16   0.597765  0.583333  0.532126
# 0    0.777952  0.743750  0.711543
# 47   0.635656  0.609375  0.597642
# 3    0.661411  0.656250  0.613353
# 26   0.687883  0.718750  0.688031
# 1    0.692500  0.700000  0.664997
# 28   0.675970  0.665625  0.635814
# 6    0.839236  0.795000  0.767389
# 11   0.842084  0.782500  0.765571
# 33   0.878524  0.840000  0.825439
# 32   0.880383  0.840000  0.830002
# 7    0.878171  0.832500  0.820845
# 34   0.899073  0.877500  0.866227

# %%
sns.barplot(df.loc[max_acc_rows], x='dataset', y='test_acc', hue='preprocess_mode')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'lab'), Text(1, 0, 'lab+maria'), Text(2, 0, 'lab+pasi')])

# %%
sns.scatterplot(df.loc[max_acc_rows], x='dataset', y='test_acc', hue='preprocess_mode')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'lab'), Text(1, 0, 'lab+maria'), Text(2, 0, 'lab+pasi')])

# %%
df.to_csv('test.csv')
